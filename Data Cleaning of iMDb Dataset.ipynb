# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('IMDb movies.csv')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (85855, 22)

# %%
df.describe()
# Out:
#            duration      avg_vote         votes     metascore  \
# count  85855.000000  85855.000000  8.585500e+04  13305.000000
# mean     100.351418      5.898656  9.493490e+03     55.896881
# std       22.553848      1.234987  5.357436e+04     17.784874
# min       41.000000      1.000000  9.900000e+01      1.000000
# 25%       88.000000      5.200000  2.050000e+02     43.000000
# 50%       96.000000      6.100000  4.840000e+02     57.000000
# 75%      108.000000      6.800000  1.766500e+03     69.000000
# max      808.000000      9.900000  2.278845e+06    100.000000
#
#        reviews_from_users  reviews_from_critics
# count        78258.000000          74058.000000
# mean            46.040826             27.479989
# std            178.511411             58.339158
# min              1.000000              1.000000
# 25%              4.000000              3.000000
# 50%              9.000000              8.000000
# 75%             27.000000             23.000000
# ...

# %%
lst = list(df.columns)
lst
# Out:
# ['imdb_title_id',
#  'title',
#  'original_title',
#  'year',
#  'date_published',
#  'genre',
#  'duration',
#  'country',
#  'language',
#  'director',
#  'writer',
#  'production_company',
#  'actors',
#  'description',
#  'avg_vote',
#  'votes',
#  'budget',
#  'usa_gross_income',
#  'worlwide_gross_income',
#  'metascore',
#  'reviews_from_users',
#  'reviews_from_critics']

# %%
for i in lst:
    print(i + ': ' + str(df[i].isnull().sum()))
# Out:
# imdb_title_id: 0
# title: 0
# original_title: 0
# year: 0
# date_published: 0
# genre: 0
# duration: 0
# country: 64
# language: 833
# director: 87
# writer: 1572
# production_company: 4455
# actors: 69
# description: 2115
# avg_vote: 0
# votes: 0
# budget: 62145
# usa_gross_income: 70529
# worlwide_gross_income: 54839
# metascore: 72550
# reviews_from_users: 7597
# reviews_from_critics: 11797

# %%
df.drop(columns = ['usa_gross_income', 'worlwide_gross_income', 'metascore', 'budget', 'reviews_from_critics'], inplace = True)

# %%
df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                 Den sorte dr��m
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286              Sokagin ��ocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     26-12-1906
# 2                     Den sorte dr��m  1911     19-08-1911
# 3                           Cleopatra  1912     13-11-1912
# ...

# %%
df.dropna(inplace = True)

# %%
lst = list(df.columns)
for i in lst:
    print(i + ': ' + str(df[i].isnull().sum()))
# Out:
# title: 0
# original_title: 0
# year: 0
# date_published: 0
# genre: 0
# duration: 0
# country: 0
# language: 0
# director: 0
# writer: 0
# production_company: 0
# actors: 0
# description: 0
# avg_vote: 0
# votes: 0
# reviews_from_users: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72043 entries, tt0000009 to tt9911196
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               72043 non-null  object
#  1   original_title      72043 non-null  object
#  2   year                72043 non-null  object
#  3   date_published      72043 non-null  object
#  4   genre               72043 non-null  object
#  5   duration            72043 non-null  int64
#  6   country             72043 non-null  object
#  7   language            72043 non-null  object
#  8   director            72043 non-null  object
#  9   writer              72043 non-null  object
#  10  production_company  72043 non-null  object
#  11  actors              72043 non-null  object
#  12  description         72043 non-null  object
#  13  avg_vote            72043 non-null  float64
#  14  votes               72043 non-null  int64
# ...

# %%
df['year'] = df['year'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72043 entries, tt0000009 to tt9911196
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               72043 non-null  object
#  1   original_title      72043 non-null  object
#  2   year                72043 non-null  object
#  3   date_published      72043 non-null  object
#  4   genre               72043 non-null  object
#  5   duration            72043 non-null  int64
#  6   country             72043 non-null  object
#  7   language            72043 non-null  object
#  8   director            72043 non-null  object
#  9   writer              72043 non-null  object
#  10  production_company  72043 non-null  object
#  11  actors              72043 non-null  object
#  12  description         72043 non-null  object
#  13  avg_vote            72043 non-null  float64
#  14  votes               72043 non-null  int64
# ...

# %%
df['year'] = df['year'].str.replace('\D+', '')
# Out:
# /var/folders/1b/nl1207l54f97q0fjf85hmxsr0000gn/T/ipykernel_45155/119400761.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['year'] = df['year'].str.replace('\D+', '')

# %%
df['year'] = pd.to_datetime(df['year'], format = '%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72043 entries, tt0000009 to tt9911196
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               72043 non-null  object
#  1   original_title      72043 non-null  object
#  2   year                72043 non-null  datetime64[ns]
#  3   date_published      72043 non-null  object
#  4   genre               72043 non-null  object
#  5   duration            72043 non-null  int64
#  6   country             72043 non-null  object
#  7   language            72043 non-null  object
#  8   director            72043 non-null  object
#  9   writer              72043 non-null  object
#  10  production_company  72043 non-null  object
#  11  actors              72043 non-null  object
#  12  description         72043 non-null  object
#  13  avg_vote            72043 non-null  float64
#  14  votes               72043 non-null  int64
# ...
